# %% [markdown]
# <a href="https://colab.research.google.com/github/ezinneanne/Wikimedia-outreachy-contribution/blob/main/EzinneAnne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/My Drive/Task_2_Intern.csv", delimiter=";")

# %%
data.head()
# Out:
#                                                 urls
# 0  http://jogandocomelas.com.br/rosana-augusto-jo...
# 1  http://maquinadoesporte.uol.com.br/artigo/por-...
# 2  http://mngr.saopaulofc.net/media/164076/spfc_b...
# 3  http://paginasmemoria.cruzeirodosul.inf.br/pag...
# 4  http://sportsillustrated.cnn.com/soccer/wusa/2...

# %%
# Function to get status code
def get_status(url):
    try:
        response = requests.get(url, timeout=5)
        return response.status_code
    except requests.exceptions.RequestException:
        return "Error"

# loop through the URLs and print their status codes and url
for url in data['urls']:
    status = get_status(url)
    print(f"({status}) {url}")
# Out:
# (Error) http://jogandocomelas.com.br/rosana-augusto-jogadora-do-santos-e-da-selecao-brasileira-anuncia-aposentadoria/
# (Error) http://maquinadoesporte.uol.com.br/artigo/por-time-feminino-corinthians-faz-parceria-com-gremio-osasco-audax_29655.html
# (Error) http://mngr.saopaulofc.net/media/164076/spfc_book_futebol_feminino_paulista_1997.pdf
# (Error) http://paginasmemoria.cruzeirodosul.inf.br/paginas/2000/12/18/20001218028520espa0800cruz.pdf
# (Error) http://sportsillustrated.cnn.com/soccer/wusa/2001/championship/news/2001/08/25/wusa_championship/
# (200) http://sportv.globo.com/site/noticia/2011/11/em-casa-sao-jose-vence-colo-colo-e-e-campeao-da-libertadores-feminina.html
# (200) http://sportv.globo.com/site/programas/rio-2016/noticia/2016/08/apos-vitoria-formiga-supera-cafu-em-jogos-pela-selecao-nunca-imaginei.html
# (200) http://www.bayareasportsdrive.com/soccer/sissi.htm
# (200) http://www.bolabrasilmulher.com.br/conheca-a-chu-santos-atacante-convocada-pela-tecnica-emily-lima/
# ...
